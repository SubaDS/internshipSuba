# %%
import pandas as pd
import requests
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the necessary library/depenencies

# %%
#reading the csv files and listing the datas
df = pd.read_csv("C:/Users/Premium/Downloads/winequality-red.csv")
df.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# # Data Analysis

# %%
df.sample(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 664            12.1             0.400         0.52             2.0      0.092
# 1484            6.8             0.910         0.06             2.0      0.060
# 870             7.7             0.715         0.01             2.1      0.064
# 198             5.4             0.835         0.08             1.2      0.046
# 210             9.7             0.530         0.60             2.0      0.039
# 712             8.7             0.690         0.00             3.2      0.084
# 749             7.3             0.510         0.18             2.1      0.070
# 1573            6.0             0.580         0.20             2.4      0.075
# 221             7.4             0.530         0.26             2.0      0.101
# 644             9.9             0.540         0.45             2.3      0.071
# 821             4.9             0.420         0.00             2.1      0.048
# ...

# %% [markdown]
# #Analysing the random sample values from the dataset.
# So by looking at the above dataset I can see that the column quality is the target label and other columns are used to predict our label. This has  to be a Classification problem!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#  this step helps to analyse the no. of enteries ,columns and mainly non-null counts.
# So there is no non-null value and it seems to be a very good dataset.

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # this step we perform to check for the statistical values like mean,std,percentile values.
# I HAVE infered from the above analysis
#
# 1.There is a huge gap between 75% and max value of total sulfur dioxide column
# 2.There is a huge gap between 75% and max value of residual sugar.
# All these gaps indicate that there are outliers present in our dataset.

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %% [markdown]
#     # This step is done to compare the quality values with the other chemicalsubstances.here we have infered that
#     1.when quality is high the volatile acidity is less and then the alcohol variant increases.
#
#     by grouping the quality we can check the ratio of mixuture in wine quality.

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# # Count Plot

# %%
sns.countplot(df['quality'])
plt.show()

# %% [markdown]
# In the countplot, the number of data present for red wine quality score 5 and 6 is higher than others. This indicates an imbalance which will need to be rectified so that our machine learning model do not get biased to a certain value during prediction.

# %%
sns.countplot(df['alcohol'])
plt.show()

# %% [markdown]
# # Box Plot

# %%
df.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# fixed acidity              AxesSubplot(0.125,0.712609;0.168478x0.167391)
# volatile acidity        AxesSubplot(0.327174,0.712609;0.168478x0.167391)
# citric acid             AxesSubplot(0.529348,0.712609;0.168478x0.167391)
# residual sugar          AxesSubplot(0.731522,0.712609;0.168478x0.167391)
# chlorides                  AxesSubplot(0.125,0.511739;0.168478x0.167391)
# free sulfur dioxide     AxesSubplot(0.327174,0.511739;0.168478x0.167391)
# total sulfur dioxide    AxesSubplot(0.529348,0.511739;0.168478x0.167391)
# density                 AxesSubplot(0.731522,0.511739;0.168478x0.167391)
# pH                          AxesSubplot(0.125,0.31087;0.168478x0.167391)
# sulphates                AxesSubplot(0.327174,0.31087;0.168478x0.167391)
# alcohol                  AxesSubplot(0.529348,0.31087;0.168478x0.167391)
# quality                  AxesSubplot(0.731522,0.31087;0.168478x0.167391)
# dtype: object

# %% [markdown]
# By  using box plot we checked for all the factors the ranges and the outliers present for all.each factor can also be checked seperately for better analysis.

# %%
df['fixed acidity'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# For the factor fixed acidity there are more number of outliers present.

# %%
df['quality'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature Selection

# %%
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 378            11.4             0.625         0.66             6.2      0.088
# 1281            7.1             0.460         0.20             1.9      0.077
# 1294            8.2             0.635         0.10             2.1      0.073
# 787            10.0             0.560         0.24             2.2      0.079
# 532            11.9             0.380         0.49             2.7      0.098
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 378                   6.0                  24.0  0.99880  3.11       0.99
# 1281                 28.0                  54.0  0.99560  3.37       0.64
# 1294                 25.0                  60.0  0.99638  3.29       0.75
# 787                  19.0                  58.0  0.99910  3.18       0.56
# 532                  12.0                  42.0  1.00040  3.16       0.61
#
#       alcohol  quality
# 378      13.3        6
# ...

# %%
# Create Classification version of target variable

# if wine quality is 7 or above we consider goodquality wine

df['goodquality']=[1 if x >= 7 else 0 for x in df['quality']]

df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 307            10.3             0.410         0.42            2.40      0.213
# 1351            7.2             0.620         0.01            2.30      0.065
# 382             8.3             0.260         0.42            2.00      0.080
# 406             9.8             0.440         0.47            2.50      0.063
# 1430            7.4             0.410         0.24            1.80      0.066
# 438            10.4             0.410         0.55            3.20      0.076
# 469             8.7             0.820         0.02            1.20      0.070
# 1514            6.9             0.840         0.21            4.10      0.074
# 818             7.1             0.715         0.00            2.35      0.071
# 310            10.3             0.530         0.48            2.50      0.063
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#seperate dependent and target variables

X = df.drop(['quality','goodquality'], axis = 1)
Y = df['goodquality']

# %%
#check for the number of goodquality wines 
df['goodquality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: goodquality, dtype: int64

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: goodquality, Length: 1599, dtype: int64

# %% [markdown]
# # Importance of each features

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

from sklearn.ensemble import ExtraTreesClassifier
classifiern = ExtraTreesClassifier()
classifiern.fit(X,Y)
score = classifiern.feature_importances_
print(score)
# Out:
# [0.07613193 0.10155159 0.09544602 0.07360779 0.0689262  0.0686092
#  0.08394314 0.08548593 0.06794237 0.11159992 0.1667559 ]

# %% [markdown]
# #Here we can see each feature importance in giving a good quality wine.(0.166).
# #alcholol feature is considered more important than other in getting a good quality wine.

# %% [markdown]
# # Splitting the datasets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
Y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score,confusion_matrix
print("Accuracy Score:",accuracy_score(Y_test,Y_pred))
# Out:
# Accuracy Score: 0.8708333333333333

# %%
confusion_mat = confusion_matrix(Y_test,Y_pred)
print(confusion_mat)
# Out:
# [[398  19]
#  [ 43  20]]

# %% [markdown]
# # Using KNN model

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.8729166666666667

# %% [markdown]
# # Using SVC model

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
pred_y = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,pred_y))
# Out:
# Accuracy Score: 0.86875

# %% [markdown]
# # Using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=7)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.8645833333333334

# %% [markdown]
# # Using Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train,Y_train)
y_pred3 = model3.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred3))
# Out:
# Accuracy Score: 0.8333333333333334

# %% [markdown]
# # Using RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(X_train, Y_train)
y_pred2 = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred2))
# Out:
# Accuracy Score: 0.89375

# %% [markdown]
# # Using XGBOOST

# %%
import xgboost as xgb

model5 = xgb.XGBClassifier(random_state=1)
model5.fit(X_train, Y_train)
y_pred5 = model5.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred5))

# %% [markdown]
# # Results Dataframe

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','KNN', 'SVC','Decision Tree' ,'GaussianNB','Random Forest','Xgboost'],
    'Score': [0.870,0.872,0.868,0.864,0.833,0.893,0.879]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df
# Out:
#                      Model
# Score
# 0.893        Random Forest
# 0.879              Xgboost
# 0.872                  KNN
# 0.870  Logistic Regression
# 0.868                  SVC
# 0.864        Decision Tree
# 0.833           GaussianNB

# %% [markdown]
# ####  Thus i sugeest we can use Rainforest model for training the model.####
